# %%
number_list = []
number_list.append(1)
number_list.append(2)
number_list.append(3)
number_list.append(4)
number_list.append(5)
print("number_list : ",number_list)
# Out:
# number_list :  [1, 2, 3, 4, 5]

# %%
number_list = []
for number in range(1, 6):
  number_list.append(number)
print("number_list : ",number_list)
# Out:
# number_list :  [1, 2, 3, 4, 5]

# %%
number_list = list(range(1, 6))
print("number_list : ",number_list)
# Out:
# number_list :  [1, 2, 3, 4, 5]

# %%
number_list = [number for number in range(1,6)]
print("number_list : ",number_list)
# Out:
# number_list :  [1, 2, 3, 4, 5]

# %%
number_list = [number-1 for number in range(1,6)]
print("number_list : ",number_list)
# Out:
# number_list :  [0, 1, 2, 3, 4]

# %%
a_list = [number for number in range(1,6) if number % 2 == 1]
print("a_list : ",a_list)
# Out:
# a_list :  [1, 3, 5]

# %% [markdown]
# p.6

# %%
a_list = [number for number in range(1,6) if number % 2 == 1]
print(a_list)
# Out:
# [1, 3, 5]

# %%
a_list = []
for number in range(1,6):
  if number%2 == 1:
    a_list.append(number)
print(a_list)
# Out:
# [1, 3, 5]

# %% [markdown]
# p.7

# %%
sentence = ['I', 'Love', 'Python','Soooooo','MUCH!!!']
# 함수 적용
wl = [word.lower() for word in sentence]
# 조건 적용
w_6 = [word for word in sentence if len(word) > 6]
# 함수 적용하여 튜플로 저장
w = [(x, x ** 2, x ** 3) for x in range(10)]
print(wl)
print(w_6)
print(w)
# Out:
# ['i', 'love', 'python', 'soooooo', 'much!!!']
# ['Soooooo', 'MUCH!!!']
# [(0, 0, 0), (1, 1, 1), (2, 4, 8), (3, 9, 27), (4, 16, 64), (5, 25, 125), (6, 36, 216), (7, 49, 343), (8, 64, 512), (9, 81, 729)]

# %% [markdown]
# p.8

# %%
rows = range(1,4)
cols = range(1,3)
for row in rows:
  for col in cols:
    print(row, col)
# Out:
# 1 1
# 1 2
# 2 1
# 2 2
# 3 1
# 3 2

# %%
rows = range(1,4)
cols = range(1,3)
cells = [(row, col) for row in rows for col in cols]
for cell in cells:
  print(cell)
# Out:
# (1, 1)
# (1, 2)
# (2, 1)
# (2, 2)
# (3, 1)
# (3, 2)

# %%
[(i,j) for i in range(5) for j in range(i)]
# Out:
# [(1, 0),
#  (2, 0),
#  (2, 1),
#  (3, 0),
#  (3, 1),
#  (3, 2),
#  (4, 0),
#  (4, 1),
#  (4, 2),
#  (4, 3)]

# %% [markdown]
# p.9

# %%
word = 'letters'
letter_counts = {letter: word.count(letter) for letter in word}
print(letter_counts)
# Out:
# {'l': 1, 'e': 2, 't': 2, 'r': 1, 's': 1}

# %% [markdown]
# p.10

# %%
word = 'letters'
letter_counts = {letter: word.count(letter) for letter in word}
print(letter_counts)
# Out:
# {'l': 1, 'e': 2, 't': 2, 'r': 1, 's': 1}

# %%
word = 'letters'
letter_counts = {letter: word.count(letter) for letter in set(word)}
print(letter_counts)
# Out:
# {'t': 2, 's': 1, 'l': 1, 'r': 1, 'e': 2}

# %% [markdown]
# p.11

# %%
a_set = {number for number in range(1,6) if number % 3 == 1}
print(a_set)
# Out:
# {1, 4}

# %% [markdown]
# p.15

# %%
def sum(param1, param2):
  return param1+param2

# %%
print(sum(1,2))
print(sum(1.3,2.2))
print(sum("python"," test"))
# Out:
# 3
# 3.5
# python test

# %% [markdown]
# p.16

# %%
days = ['Monday', 'Tuesday', 'Wednesday']
fruits = ['banana', 'orange', 'peach']
drinks = ['coffee', 'tea', 'beer']
desserts = ['tiramisu', 'ice cream', 'pie', 'pudding']
for day, fruit, drink, dessert in zip(days, fruits, drinks, desserts):
  print(day, ": drink", drink, "- eat", fruit, "- enjoy", dessert)
# Out:
# Monday : drink coffee - eat banana - enjoy tiramisu
# Tuesday : drink tea - eat orange - enjoy ice cream
# Wednesday : drink beer - eat peach - enjoy pie

# %% [markdown]
# p.17

# %%
english = 'Monday', 'Tuesday', 'Wednesday'
french ='Lundi', 'Mardi','Mercredi'
print(list( zip(english, french) ))
print(dict( zip(english, french) ))
# Out:
# [('Monday', 'Lundi'), ('Tuesday', 'Mardi'), ('Wednesday', 'Mercredi')]
# {'Monday': 'Lundi', 'Tuesday': 'Mardi', 'Wednesday': 'Mercredi'}

# %% [markdown]
# p.18

# %%
def menu(wine, entree, dessert):
  return {'wine': wine, 'entree': entree, 'dessert': dessert}

print(menu('chardonnay', 'chicken', 'cake'))
# Out:
# {'wine': 'chardonnay', 'entree': 'chicken', 'dessert': 'cake'}

# %% [markdown]
# p.19

# %%
print(menu(entree='beef', dessert='bagel', wine='bordeaux'))
print(menu('frontenac', dessert='flan', entree='fish'))
# Out:
# {'wine': 'bordeaux', 'entree': 'beef', 'dessert': 'bagel'}
# {'wine': 'frontenac', 'entree': 'fish', 'dessert': 'flan'}

# %% [markdown]
# p.20

# %%
def menu(wine, entree, dessert='pudding'):
  return {'wine': wine, 'entree': entree, 'dessert': dessert}
print(menu('chardonnay', 'chicken'))
print(menu('dunkelfelder', 'duck', 'doughnut'))
# Out:
# {'wine': 'chardonnay', 'entree': 'chicken', 'dessert': 'pudding'}
# {'wine': 'dunkelfelder', 'entree': 'duck', 'dessert': 'doughnut'}

# %% [markdown]
# p.21

# %%
def menu(price, wine='chardonnay', entree='chicken', dessert='pudding'):
  return {'price': price, 'wine': wine, 'entree': entree, 'dessert': dessert}

print(menu(100))
print(menu(price=100))
print(menu(price=120, entree='beef'))
print(menu(dessert='bagel', price=110))
print(menu('eighty', 'saint-pierre', 'fish'))
print(menu('hundred', wine='saint-pierre'))
# Out:
# {'price': 100, 'wine': 'chardonnay', 'entree': 'chicken', 'dessert': 'pudding'}
# {'price': 100, 'wine': 'chardonnay', 'entree': 'chicken', 'dessert': 'pudding'}
# {'price': 120, 'wine': 'chardonnay', 'entree': 'beef', 'dessert': 'pudding'}
# {'price': 110, 'wine': 'chardonnay', 'entree': 'chicken', 'dessert': 'bagel'}
# {'price': 'eighty', 'wine': 'saint-pierre', 'entree': 'fish', 'dessert': 'pudding'}
# {'price': 'hundred', 'wine': 'saint-pierre', 'entree': 'chicken', 'dessert': 'pudding'}

# %% [markdown]
# p.22

# %%
def menu(price, wine='chardonnay', entree='chicken', dessert='pudding'):
  return {'price': price, 'wine': wine, 'entree': entree, 'dessert': dessert}

menu()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3775/709822247.py in <cell line: 0>()
#       2   return {'price': price, 'wine': wine, 'entree': entree, 'dessert': dessert}
#       3
# ----> 4 menu()
#
# TypeError: menu() missing 1 required positional argument: 'price'

# %%
menu(price=100, 'saint-pierre')
# Out:
#   File "/tmp/ipykernel_3775/2276001416.py", line 1
#     menu(price=100, 'saint-pierre')
#                                   ^
# SyntaxError: positional argument follows keyword argument

# %%
menu(100, price=120)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3775/215135410.py in <cell line: 0>()
# ----> 1 menu(100, price=120)
#
# TypeError: menu() got multiple values for argument 'price'

# %%
menu(main='cream pasta')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3775/457093143.py in <cell line: 0>()
# ----> 1 menu(main='cream pasta')
#
# TypeError: menu() got an unexpected keyword argument 'main'

# %% [markdown]
# p.23

# %%
def echo(anything):
  'echo returns its input argument'
  return anything
def print_if_true(thing, check):
  """
  Prints the first argument if a second argument is true.
  The operation is:
  1. Check whether the *second* argument is true.
  2. If it is, print the *first* argument.
  """
  if check:
    print(thing)
help(echo)
print(echo.__doc__)
# Out:
# Help on function echo in module __main__:
#
# echo(anything)
#     echo returns its input argument
#
# echo returns its input argument
